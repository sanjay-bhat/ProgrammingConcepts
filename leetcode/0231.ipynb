// %% [markdown]
// # 231. Power of Two
// https://leetcode.com/problems/power-of-two/
//
// ## Complexity Comparison
//
// | Approach | Time | Space | Notes |
// |----------|------|-------|-------|
// | Bit manipulation | $O(1)$ | $O(1)$ | Optimal — `n & (n-1) == 0` |
// | Loop / divide by 2 | $O(\log n)$ | $O(1)$ | Repeatedly divide |
//
// ## Methodology
//
// A power of two in binary has exactly one bit set (e.g., 1, 10, 100, 1000). The expression `n & (n-1)` clears the lowest set bit. If the result is 0, then n had exactly one set bit, meaning it is a power of two. We also check n > 0 since 0 and negatives are not powers of two.

// %% [markdown]
// ## Solutions
//
// ### C#

// %%
public class Solution {
    public bool IsPowerOfTwo(int n) {
        return n > 0 && (n & (n - 1)) == 0;
    }
}

// %% [markdown]
// ### Python

// %%
class Solution:
    def isPowerOfTwo(self, n: int) -> bool:
        return n > 0 and (n & (n - 1)) == 0

// %% [markdown]
// ### Go

// %%
func isPowerOfTwo(n int) bool {
    return n > 0 && n&(n-1) == 0
}

// %% [markdown]
// ### Rust

// %%
impl Solution {
    pub fn is_power_of_two(n: i32) -> bool {
        n > 0 && (n & (n - 1)) == 0
    }
}

// %% [markdown]
// ## Example Scenarios
//
// 1. **n = 1** — $2^0 = 1$, return true.
// 2. **n = 16** — $2^4 = 16$, return true.
// 3. **n = 3** — Not a power of two, return false.
// 4. **n = 0** — Zero is not a power of two, return false.
// 5. **n = -2** — Negative, return false.

// %% [markdown]
// ![image](attachment:image.png)
