// %% [markdown]
// # 258. Add Digits
// https://leetcode.com/problems/add-digits/
//
// ## Complexity Comparison
//
// | Approach | Time | Space | Description |
// |----------|------|-------|-------------|
// | Simulation | O(log n) | O(1) | Repeatedly sum digits until single digit |
// | **Digital Root (Optimal)** | **O(1)** | **O(1)** | Mathematical formula using modulo 9 |
//
// ## Methodology
//
// The digital root of a number can be computed with a formula: for any positive number, the digital root is `1 + (num - 1) % 9`. This is because the digital root cycles through 1-9 for positive integers. For 0, the result is 0.

// %% [markdown]
// ## Solutions
//
// ### C#

// %%
public class Solution {
    public int AddDigits(int num) {
        if (num == 0) return 0;
        return 1 + (num - 1) % 9;
    }
}

// %% [markdown]
// ### Python

// %%
class Solution:
    def addDigits(self, num: int) -> int:
        if num == 0:
            return 0
        return 1 + (num - 1) % 9

// %% [markdown]
// ### Go

// %%
func addDigits(num int) int {
    if num == 0 {
        return 0
    }
    return 1 + (num - 1) % 9
}

// %% [markdown]
// ### Rust

// %%
impl Solution {
    pub fn add_digits(num: i32) -> i32 {
        if num == 0 { return 0; }
        1 + (num - 1) % 9
    }
}

// %% [markdown]
// ## Example Scenarios
//
// 1. **`num = 38`** - 3+8=11, 1+1=2. Digital root: 1+(38-1)%9 = 1+1 = 2. Returns `2`.
//
// 2. **`num = 0`** - Already a single digit. Returns `0`.
//
// 3. **`num = 9`** - Single digit. 1+(9-1)%9 = 1+8%9 = 1+8 = 9. Returns `9`.
//
// 4. **`num = 18`** - 1+8=9. Digital root: 1+(18-1)%9 = 1+8 = 9. Returns `9`.
//
// 5. **`num = 199`** - 1+9+9=19, 1+9=10, 1+0=1. Digital root: 1+(199-1)%9 = 1+0 = 1. Returns `1`.

// %% [markdown]
// ![image](attachment:image.png)
